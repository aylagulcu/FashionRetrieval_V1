# %%
experiment_name= "KaggleFashion_pretrain_classification_resnet34"

# %%
import glob
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.core.common import flatten
import numpy as np
import random

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader

from datasets import *
import networks
import utils


import ast
import PIL

# %%
#######################################################
#                  Create Dataset
#######################################################
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

transform = transforms.Compose([transforms.ToPILImage(),
                                transforms.Resize(255),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()])

#######################################################
#                  Create Dataset
#######################################################
# dataset_train = datasets.FashionProductsDataset(img_dir="./images",train_path="DeepFashionDataset_train.csv",mode="train", transform= transform)
dataset_train = FashionProductsDataset(img_dir="./Kaggle_fashion/images", styles_dir="./Kaggle_fashion/styles.csv")
# Out:
# /tmp/ipykernel_9116/161129884.py:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   dataset_train = FashionProductsDataset(img_dir="./Kaggle_fashion/images", styles_dir="./Kaggle_fashion/styles.csv")
# /tmp/ipykernel_9116/161129884.py:16: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   dataset_train = FashionProductsDataset(img_dir="./Kaggle_fashion/images", styles_dir="./Kaggle_fashion/styles.csv")

# %%
len(dataset_train)
# Out:
# 44419

# %%
dataset_train.classes_set
# Out:
# ['Apparel/Topwear',
#  'Apparel/Bottomwear',
#  'Accessories/Watches',
#  'Accessories/Socks',
#  'Footwear/Shoes',
#  'Accessories/Belts',
#  'Footwear/Flip Flops',
#  'Accessories/Bags',
#  'Apparel/Innerwear',
#  'Footwear/Sandal',
#  'Accessories/Shoe Accessories',
#  'Personal Care/Fragrance',
#  'Accessories/Jewellery',
#  'Personal Care/Lips',
#  'Apparel/Saree',
#  'Accessories/Eyewear',
#  'Personal Care/Nails',
#  'Accessories/Scarves',
#  'Apparel/Dress',
#  'Apparel/Loungewear and Nightwear',
#  'Accessories/Wallets',
#  'Apparel/Apparel Set',
#  'Accessories/Headwear',
#  'Accessories/Mufflers',
#  'Personal Care/Skin Care',
#  'Personal Care/Makeup',
#  'Free Items/Free Gifts',
#  'Accessories/Ties',
#  'Accessories/Accessories',
#  'Personal Care/Skin',
#  'Personal Care/Beauty Accessories',
#  'Accessories/Water Bottle',
#  'Personal Care/Eyes',
#  'Personal Care/Bath and Body',
#  'Accessories/Gloves',
#  'Accessories/Sports Accessories',
#  'Accessories/Cufflinks',
#  'Sporting Goods/Sports Equipment',
#  'Accessories/Stoles',
#  'Personal Care/Hair',
#  'Apparel/Socks',
#  'Personal Care/Perfumes',
#  'Home/Home Furnishing',
#  'Accessories/Umbrellas',
#  'Sporting Goods/Wristbands',
#  'Accessories/Perfumes',
#  'Free Items/Vouchers']

# %%
len(dataset_train.classes_set)
# Out:
# 47

# %%
dataset_train.classes[:5]
# Out:
# ['Apparel/Topwear',
#  'Apparel/Bottomwear',
#  'Accessories/Watches',
#  'Apparel/Bottomwear',
#  'Apparel/Topwear']

# %%
import matplotlib.pyplot as plt 
plt.imshow(dataset_train.__getitem__(0)[0].permute(1, 2, 0) )
# Out:
# /home/ayla/Desktop/DeepFashion_Consumer-to-shop Clothes Retrieval Benchmark/datasets.py:74: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   img_tensor = torch.from_numpy(np.asarray(image))

# %% [markdown]
# ### # Create valid data set:

# %%
from torch.utils.data.sampler import SubsetRandomSampler
# percentage of training set to use as validation
valid_size = 0.3

# obtain training indices that will be used for validation
num_train= len(dataset_train)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
batch_size= 4
# number of subprocesses to use for data loading
num_workers = 0

# prepare data loaders:
train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)

# %%
# Visualize some sample data
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

# %%
images.shape
# Out:
# (4, 3, 300, 300)

# %%
labels.shape
# Out:
# torch.Size([4])

# %%
labels
# Out:
# tensor([4, 8, 4, 4])

# %%
print([dataset_train.classes_set[i.item()] for i in labels ])
# Out:
# ['Footwear/Shoes', 'Apparel/Innerwear', 'Footwear/Shoes', 'Footwear/Shoes']

# %%
# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(8, 8))
for idx in np.arange(batch_size):
    ax = fig.add_subplot(2, batch_size//2, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    ax.set_title(dataset_train.classes_set[labels[idx].item()], fontfamily='serif', loc='left', fontsize='medium', color= 'red')

# %%
# check if CUDA is available
cuda = torch.cuda.is_available()

if not cuda:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
train_loader.dataset.classes_set
# Out:
# ['Apparel/Topwear',
#  'Apparel/Bottomwear',
#  'Accessories/Watches',
#  'Accessories/Socks',
#  'Footwear/Shoes',
#  'Accessories/Belts',
#  'Footwear/Flip Flops',
#  'Accessories/Bags',
#  'Apparel/Innerwear',
#  'Footwear/Sandal',
#  'Accessories/Shoe Accessories',
#  'Personal Care/Fragrance',
#  'Accessories/Jewellery',
#  'Personal Care/Lips',
#  'Apparel/Saree',
#  'Accessories/Eyewear',
#  'Personal Care/Nails',
#  'Accessories/Scarves',
#  'Apparel/Dress',
#  'Apparel/Loungewear and Nightwear',
#  'Accessories/Wallets',
#  'Apparel/Apparel Set',
#  'Accessories/Headwear',
#  'Accessories/Mufflers',
#  'Personal Care/Skin Care',
#  'Personal Care/Makeup',
#  'Free Items/Free Gifts',
#  'Accessories/Ties',
#  'Accessories/Accessories',
#  'Personal Care/Skin',
#  'Personal Care/Beauty Accessories',
#  'Accessories/Water Bottle',
#  'Personal Care/Eyes',
#  'Personal Care/Bath and Body',
#  'Accessories/Gloves',
#  'Accessories/Sports Accessories',
#  'Accessories/Cufflinks',
#  'Sporting Goods/Sports Equipment',
#  'Accessories/Stoles',
#  'Personal Care/Hair',
#  'Apparel/Socks',
#  'Personal Care/Perfumes',
#  'Home/Home Furnishing',
#  'Accessories/Umbrellas',
#  'Sporting Goods/Wristbands',
#  'Accessories/Perfumes',
#  'Free Items/Vouchers']

# %%
dataset_train.labels
# Out:
# array([ 0,  1,  2, ...,  0, 11,  2])

# %%
batch_size= 128
num_workers = 0 # number of subprocesses to use for data loading

# prepare data loaders:
train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)

# %%
# Load the pretrained model from pytorch
embedding_net= torchvision.models.resnet34(pretrained=True)

# print out the model structure
print(embedding_net)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
# /home/ayla/anaconda3/envs/fashion/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ayla/anaconda3/envs/fashion/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Un-Freeze training for all layers parameters:
for param in embedding_net.parameters():
    param.required_grad = True

# %%
embedding_net.fc= nn.Sequential(nn.Linear(512, 128),
                                nn.BatchNorm1d(128),
                                nn.ReLU(),
                                nn.Linear(128, 47)
                                )

# %%
# Un-Freeze training for all layers parameters:
for param in embedding_net.parameters():
    param.required_grad = True

# %%
model= embedding_net

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
device = torch.device('cuda')
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=128, out_features=47, bias=True)
#   )
# )

# %%
def train_epoch(train_loader, model, loss_fn, optimizer, log_interval, cuda): 
    
    ###################
    # train the model #
    ###################
    model.train()

   # keep track of training loss
    train_loss = 0.0
    train_acc = 0.0
    nbr_class= 47
    class_correct = list(0. for i in range(nbr_class))
    class_total = list(0. for i in range(nbr_class))
    class_acc= list(0. for i in range(nbr_class))
    
    losses = []

    for batch_idx, (data, target) in enumerate(train_loader):

        # data.float():  due to Kaggle fashion item dataset error: RuntimeError: Input type (torch.cuda.ByteTensor) and weight type (torch.cuda.FloatTensor) should be the same
        
        # move tensors to GPU if CUDA is available
        if cuda:
            data, target= data.float().to(device), target.to(device)

        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        
        # forward pass: create embeddings of the inputs
        outputs = model(data)

        # append targets to the end of the embeddings, and calculate the batch loss
        loss = loss_fn(outputs, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        
        # perform a single optimization step (parameter update)
        optimizer.step()
        
        # update training loss
        train_loss += loss.item() # Assuming lss function returns average loss

        losses.append(loss.item())
        
        
        # convert output probabilities to predicted class
        _, pred = torch.max(outputs, 1)    
        # compare predictions to true label
        correct_tensor = pred.eq(target.data.view_as(pred))
        correct = np.squeeze(correct_tensor.numpy()) if not cuda else np.squeeze(correct_tensor.cpu().numpy())
        # calculate test accuracy for each object class
        for i in range(len(data)):
            label = target.data[i]
            class_correct[label] += correct[i].item()
            class_total[label] += 1
            
            
        
        # Provide some feedbach within one epoch
        if batch_idx % log_interval == 0:
            print('Train: [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                batch_idx * len(data[0]), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.mean(losses)))
            losses = []

    # calculate accuracy:      
    for i in range(nbr_class):
        if class_total[i] > 0:
            class_acc[i]= 100 * class_correct[i] / class_total[i]
    train_acc= np.average(class_acc)
        
    # calculate average train loss (batch average is returned)
    train_loss /= (batch_idx + 1)
    
    return train_loss, train_acc

# %%
def test_epoch(val_loader, model, loss_fn, cuda):
    
    ######################    
    # validate the model #
    ######################
    
    # keep track of validation loss
    valid_loss = 0.0
    valid_acc = 0.0
    
    nbr_class= 47
    class_correct = list(0. for i in range(nbr_class))
    class_total = list(0. for i in range(nbr_class))
    class_acc= list(0. for i in range(nbr_class))
    
    with torch.no_grad():

        model.eval()
        for batch_idx, (data, target) in enumerate(val_loader):
            data= data.float() # cast to float
            
            # move tensors to GPU if CUDA is available
            if cuda:
                data, target= data.to(device), target.to(device)

            outputs = model(data)

            loss = loss_fn(outputs, target)
             
            # update average validation loss 
            valid_loss += loss.item()
            
            
            
            
           
            # convert output probabilities to predicted class
            _, pred = torch.max(outputs, 1)    
            # compare predictions to true label
            correct_tensor = pred.eq(target.data.view_as(pred))
            correct = np.squeeze(correct_tensor.numpy()) if not cuda else np.squeeze(correct_tensor.cpu().numpy())
            # calculate test accuracy for each object class
            for i in range(len(data)):
                label = target.data[i]
                class_correct[label] += correct[i].item()
                class_total[label] += 1

                
        # calculate accuracy:      
        for i in range(nbr_class):
            if class_total[i] > 0:
                class_acc[i]= 100 * class_correct[i] / class_total[i]
        valid_acc= np.average(class_acc)
                
        # calculate average validation loss (assuming batch average is returned)
        valid_loss /= (batch_idx + 1)


    return valid_loss, valid_acc

# %%
def save_model(EPOCH, model, optimizer, LOSS): # epoch and loss are numbers
    """
    Save the trained model and the optimizer to disk.
    """      
    torch.save({
                'epoch': EPOCH,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': LOSS,
                }, experiment_name+'.pt')

# %%
start_epoch= 0
n_epochs= 100

log_interval=50

train_losses, valid_losses = [], []

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(start_epoch, n_epochs):
    
    # keep track of training and validation loss
    train_loss = 0.0
    train_acc = 0.0
    
    valid_loss = 0.0
    valid_acc = 0.0
    
    train_loss, train_acc = train_epoch(train_loader, model, loss_fn, optimizer, log_interval, cuda)
    valid_loss, valid_acc = test_epoch(valid_loader, model, loss_fn, cuda)

    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    
    # print training/validation statistics 
    print('Epoch: Epoch: {}/{} \tTraining Loss: {:.6f} \tTraining Accuracy: {:.6f} \tValid Loss: {:.6f} \tValid Acc: {:.6f}'.format(
        epoch + 1, n_epochs, train_loss, train_acc, valid_loss, valid_acc))

    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format( valid_loss_min,
                                                                                          valid_loss))
        save_model(epoch, model, optimizer, train_loss)
        valid_loss_min = valid_loss
# Out:
# Train: [0/44419 (0%)]	Loss: 0.416765
# Train: [150/44419 (21%)]	Loss: 0.243014
# Train: [300/44419 (41%)]	Loss: 0.240906
# Train: [450/44419 (62%)]	Loss: 0.243028
# Train: [600/44419 (82%)]	Loss: 0.210381
# Epoch: Epoch: 1/100 	Training Loss: 0.229396 	Training Accuracy: 47.788286 	Valid Loss: 0.220002 	Valid Acc: 48.763694
# Validation loss decreased (inf --> 0.220002).  Saving model ...
# Train: [0/44419 (0%)]	Loss: 0.210863
# Train: [150/44419 (21%)]	Loss: 0.161427
# Train: [300/44419 (41%)]	Loss: 0.161755
# Train: [450/44419 (62%)]	Loss: 0.157461
# Train: [600/44419 (82%)]	Loss: 0.170026
# Epoch: Epoch: 2/100 	Training Loss: 0.165278 	Training Accuracy: 52.485068 	Valid Loss: 0.405997 	Valid Acc: 43.629841
# Train: [0/44419 (0%)]	Loss: 0.110722
# Train: [150/44419 (21%)]	Loss: 0.135938
# Train: [300/44419 (41%)]	Loss: 0.129309
# Train: [450/44419 (62%)]	Loss: 0.144522
# Train: [600/44419 (82%)]	Loss: 0.147247
# Epoch: Epoch: 3/100 	Training Loss: 0.138422 	Training Accuracy: 55.198224 	Valid Loss: 0.204233 	Valid Acc: 54.182735
# Validation loss decreased (0.220002 --> 0.204233).  Saving model ...
# Train: [0/44419 (0%)]	Loss: 0.094136
# Train: [150/44419 (21%)]	Loss: 0.104131
# Train: [300/44419 (41%)]	Loss: 0.118879
# Train: [450/44419 (62%)]	Loss: 0.113112
# Train: [600/44419 (82%)]	Loss: 0.121482
# Epoch: Epoch: 4/100 	Training Loss: 0.115756 	Training Accuracy: 59.379377 	Valid Loss: 0.214944 	Valid Acc: 56.657904
# Train: [0/44419 (0%)]	Loss: 0.106446
# Train: [150/44419 (21%)]	Loss: 0.085374
# Train: [300/44419 (41%)]	Loss: 0.094535
# Train: [450/44419 (62%)]	Loss: 0.091575
# Train: [600/44419 (82%)]	Loss: 0.097378
# Epoch: Epoch: 5/100 	Training Loss: 0.090025 	Training Accuracy: 62.195720 	Valid Loss: 0.164266 	Valid Acc: 57.965212
# Validation loss decreased (0.204233 --> 0.164266).  Saving model ...
# Train: [0/44419 (0%)]	Loss: 0.045832
# Train: [150/44419 (21%)]	Loss: 0.060328
# Train: [300/44419 (41%)]	Loss: 0.058603
# Train: [450/44419 (62%)]	Loss: 0.068475
# Train: [600/44419 (82%)]	Loss: 0.094583
# Epoch: Epoch: 6/100 	Training Loss: 0.073911 	Training Accuracy: 65.655758 	Valid Loss: 0.189795 	Valid Acc: 60.653516
# Train: [0/44419 (0%)]	Loss: 0.098550
# Train: [150/44419 (21%)]	Loss: 0.058897
# Train: [300/44419 (41%)]	Loss: 0.054416
# Train: [450/44419 (62%)]	Loss: 0.064187
# Train: [600/44419 (82%)]	Loss: 0.063121
# Epoch: Epoch: 7/100 	Training Loss: 0.064838 	Training Accuracy: 69.076760 	Valid Loss: 0.196698 	Valid Acc: 55.349734
# Train: [0/44419 (0%)]	Loss: 0.068715
# Train: [150/44419 (21%)]	Loss: 0.062798
# Train: [300/44419 (41%)]	Loss: 0.054196
# Train: [450/44419 (62%)]	Loss: 0.048133
# Train: [600/44419 (82%)]	Loss: 0.065245
# Epoch: Epoch: 8/100 	Training Loss: 0.058421 	Training Accuracy: 69.847354 	Valid Loss: 0.172926 	Valid Acc: 60.210417
# Train: [0/44419 (0%)]	Loss: 0.020479
# Train: [150/44419 (21%)]	Loss: 0.046195
# Train: [300/44419 (41%)]	Loss: 0.044945
# Train: [450/44419 (62%)]	Loss: 0.058930
# Train: [600/44419 (82%)]	Loss: 0.051448
# Epoch: Epoch: 9/100 	Training Loss: 0.050629 	Training Accuracy: 71.562920 	Valid Loss: 0.200090 	Valid Acc: 62.590712
# Train: [0/44419 (0%)]	Loss: 0.105616
# Train: [150/44419 (21%)]	Loss: 0.034121
# Train: [300/44419 (41%)]	Loss: 0.036070
# Train: [450/44419 (62%)]	Loss: 0.031651
# Train: [600/44419 (82%)]	Loss: 0.038896
# Epoch: Epoch: 10/100 	Training Loss: 0.037646 	Training Accuracy: 76.904384 	Valid Loss: 0.228056 	Valid Acc: 63.586840
# Train: [0/44419 (0%)]	Loss: 0.005944
# Train: [150/44419 (21%)]	Loss: 0.041385
# Train: [300/44419 (41%)]	Loss: 0.051473
# Train: [450/44419 (62%)]	Loss: 0.031788
# Train: [600/44419 (82%)]	Loss: 0.037165
# Epoch: Epoch: 11/100 	Training Loss: 0.042341 	Training Accuracy: 77.204340 	Valid Loss: 0.183859 	Valid Acc: 63.600916
# Train: [0/44419 (0%)]	Loss: 0.055081
# Train: [150/44419 (21%)]	Loss: 0.033219
# Train: [300/44419 (41%)]	Loss: 0.028214
# Train: [450/44419 (62%)]	Loss: 0.026937
# Train: [600/44419 (82%)]	Loss: 0.021832
# Epoch: Epoch: 12/100 	Training Loss: 0.028647 	Training Accuracy: 81.645513 	Valid Loss: 0.173272 	Valid Acc: 68.905548
# Train: [0/44419 (0%)]	Loss: 0.031935
# Train: [150/44419 (21%)]	Loss: 0.013942
# Train: [300/44419 (41%)]	Loss: 0.017988
# Train: [450/44419 (62%)]	Loss: 0.023425
# Train: [600/44419 (82%)]	Loss: 0.040965
# Epoch: Epoch: 13/100 	Training Loss: 0.025472 	Training Accuracy: 83.623402 	Valid Loss: 0.199030 	Valid Acc: 64.312683
# Train: [0/44419 (0%)]	Loss: 0.002605
# Train: [150/44419 (21%)]	Loss: 0.024749
# Train: [300/44419 (41%)]	Loss: 0.018097
# Train: [450/44419 (62%)]	Loss: 0.021291
# Train: [600/44419 (82%)]	Loss: 0.025895
# Epoch: Epoch: 14/100 	Training Loss: 0.025038 	Training Accuracy: 85.691040 	Valid Loss: 0.235104 	Valid Acc: 63.688849
# Train: [0/44419 (0%)]	Loss: 0.015691
# Train: [150/44419 (21%)]	Loss: 0.031149
# Train: [300/44419 (41%)]	Loss: 0.023742
# Train: [450/44419 (62%)]	Loss: 0.025953
# Train: [600/44419 (82%)]	Loss: 0.027195
# Epoch: Epoch: 15/100 	Training Loss: 0.027159 	Training Accuracy: 87.355609 	Valid Loss: 0.222564 	Valid Acc: 64.210479
# Train: [0/44419 (0%)]	Loss: 0.029488
# Train: [150/44419 (21%)]	Loss: 0.028010
# Train: [300/44419 (41%)]	Loss: 0.020199
# Train: [450/44419 (62%)]	Loss: 0.022168
# Train: [600/44419 (82%)]	Loss: 0.020404
# Epoch: Epoch: 16/100 	Training Loss: 0.022803 	Training Accuracy: 88.543264 	Valid Loss: 0.199970 	Valid Acc: 65.336214
# Train: [0/44419 (0%)]	Loss: 0.001433
# Train: [150/44419 (21%)]	Loss: 0.012325
# Train: [300/44419 (41%)]	Loss: 0.013400
# Train: [450/44419 (62%)]	Loss: 0.013281
# Train: [600/44419 (82%)]	Loss: 0.023834
# Epoch: Epoch: 17/100 	Training Loss: 0.018533 	Training Accuracy: 89.598655 	Valid Loss: 0.231647 	Valid Acc: 65.498969
# Train: [0/44419 (0%)]	Loss: 0.048845
# Train: [150/44419 (21%)]	Loss: 0.024853
# Train: [300/44419 (41%)]	Loss: 0.022434
# Train: [450/44419 (62%)]	Loss: 0.027954
# Train: [600/44419 (82%)]	Loss: 0.023044
# Epoch: Epoch: 18/100 	Training Loss: 0.024278 	Training Accuracy: 87.071119 	Valid Loss: 0.199359 	Valid Acc: 65.117201
# Train: [0/44419 (0%)]	Loss: 0.000919
# Train: [150/44419 (21%)]	Loss: 0.018197
# Train: [300/44419 (41%)]	Loss: 0.013942
# Train: [450/44419 (62%)]	Loss: 0.009413
# Train: [600/44419 (82%)]	Loss: 0.007737
# Epoch: Epoch: 19/100 	Training Loss: 0.011925 	Training Accuracy: 92.366443 	Valid Loss: 0.196263 	Valid Acc: 68.612139
# Train: [0/44419 (0%)]	Loss: 0.004137
# Train: [150/44419 (21%)]	Loss: 0.007639
# Train: [300/44419 (41%)]	Loss: 0.006332
# Train: [450/44419 (62%)]	Loss: 0.011509
# Train: [600/44419 (82%)]	Loss: 0.003511
# Epoch: Epoch: 20/100 	Training Loss: 0.007401 	Training Accuracy: 93.643535 	Valid Loss: 0.191405 	Valid Acc: 69.587357
# Train: [0/44419 (0%)]	Loss: 0.001257
# Train: [150/44419 (21%)]	Loss: 0.003727
# Train: [300/44419 (41%)]	Loss: 0.003990
# Train: [450/44419 (62%)]	Loss: 0.011598
# Train: [600/44419 (82%)]	Loss: 0.012148
# Epoch: Epoch: 21/100 	Training Loss: 0.008510 	Training Accuracy: 94.953814 	Valid Loss: 0.222597 	Valid Acc: 67.440134
# Train: [0/44419 (0%)]	Loss: 0.042016
# Train: [150/44419 (21%)]	Loss: 0.012320
# Train: [300/44419 (41%)]	Loss: 0.018868
# Train: [450/44419 (62%)]	Loss: 0.032938
# Train: [600/44419 (82%)]	Loss: 0.024418
# Epoch: Epoch: 22/100 	Training Loss: 0.024174 	Training Accuracy: 88.874388 	Valid Loss: 0.221062 	Valid Acc: 61.721186
# Train: [0/44419 (0%)]	Loss: 0.021299
# Train: [150/44419 (21%)]	Loss: 0.020582
# Train: [300/44419 (41%)]	Loss: 0.017384
# Train: [450/44419 (62%)]	Loss: 0.034739
# Train: [600/44419 (82%)]	Loss: 0.021676
# Epoch: Epoch: 23/100 	Training Loss: 0.023251 	Training Accuracy: 91.604268 	Valid Loss: 0.216068 	Valid Acc: 66.649961
# Train: [0/44419 (0%)]	Loss: 0.014000
# Train: [150/44419 (21%)]	Loss: 0.012574
# Train: [300/44419 (41%)]	Loss: 0.007960
# Train: [450/44419 (62%)]	Loss: 0.011737
# Train: [600/44419 (82%)]	Loss: 0.011001
# Epoch: Epoch: 24/100 	Training Loss: 0.011710 	Training Accuracy: 94.290002 	Valid Loss: 0.226560 	Valid Acc: 67.101072
# Train: [0/44419 (0%)]	Loss: 0.000874
# Train: [150/44419 (21%)]	Loss: 0.010413
# Train: [300/44419 (41%)]	Loss: 0.010103
# Train: [450/44419 (62%)]	Loss: 0.006775
# Train: [600/44419 (82%)]	Loss: 0.009876
# Epoch: Epoch: 25/100 	Training Loss: 0.009861 	Training Accuracy: 90.954266 	Valid Loss: 0.199309 	Valid Acc: 67.549966
# Train: [0/44419 (0%)]	Loss: 0.001032
# Train: [150/44419 (21%)]	Loss: 0.006799
# Train: [300/44419 (41%)]	Loss: 0.005654
# Train: [450/44419 (62%)]	Loss: 0.006179
# Train: [600/44419 (82%)]	Loss: 0.002485
# Epoch: Epoch: 26/100 	Training Loss: 0.005217 	Training Accuracy: 93.818258 	Valid Loss: 0.209506 	Valid Acc: 69.436557
# Train: [0/44419 (0%)]	Loss: 0.000937
# Train: [150/44419 (21%)]	Loss: 0.003828
# Train: [300/44419 (41%)]	Loss: 0.006437
# Train: [450/44419 (62%)]	Loss: 0.006868
# Train: [600/44419 (82%)]	Loss: 0.006830
# Epoch: Epoch: 27/100 	Training Loss: 0.006644 	Training Accuracy: 95.194533 	Valid Loss: 0.259717 	Valid Acc: 65.776117
# Train: [0/44419 (0%)]	Loss: 0.000395
# Train: [150/44419 (21%)]	Loss: 0.021342
# Train: [300/44419 (41%)]	Loss: 0.036399
# Train: [450/44419 (62%)]	Loss: 0.026543
# Train: [600/44419 (82%)]	Loss: 0.031071
# Epoch: Epoch: 28/100 	Training Loss: 0.028348 	Training Accuracy: 85.902622 	Valid Loss: 0.236043 	Valid Acc: 65.648563
# Train: [0/44419 (0%)]	Loss: 0.025885
# Train: [150/44419 (21%)]	Loss: 0.013592
# Train: [300/44419 (41%)]	Loss: 0.020879
# Train: [450/44419 (62%)]	Loss: 0.024357
# Train: [600/44419 (82%)]	Loss: 0.020734
# Epoch: Epoch: 29/100 	Training Loss: 0.018543 	Training Accuracy: 91.634872 	Valid Loss: 0.221432 	Valid Acc: 66.814483
# Train: [0/44419 (0%)]	Loss: 0.002106
# Train: [150/44419 (21%)]	Loss: 0.006412
# Train: [300/44419 (41%)]	Loss: 0.014926
# Train: [450/44419 (62%)]	Loss: 0.012531
# Train: [600/44419 (82%)]	Loss: 0.017677
# Epoch: Epoch: 30/100 	Training Loss: 0.012098 	Training Accuracy: 94.480026 	Valid Loss: 0.206594 	Valid Acc: 67.806246
# Train: [0/44419 (0%)]	Loss: 0.007752
# Train: [150/44419 (21%)]	Loss: 0.012324
# Train: [300/44419 (41%)]	Loss: 0.007525
# Train: [450/44419 (62%)]	Loss: 0.005719
# Train: [600/44419 (82%)]	Loss: 0.009689
# Epoch: Epoch: 31/100 	Training Loss: 0.008803 	Training Accuracy: 96.431322 	Valid Loss: 0.226191 	Valid Acc: 68.996803
# Train: [0/44419 (0%)]	Loss: 0.002357
# Train: [150/44419 (21%)]	Loss: 0.006223
# Train: [300/44419 (41%)]	Loss: 0.004459
# Train: [450/44419 (62%)]	Loss: 0.005720
# Train: [600/44419 (82%)]	Loss: 0.008226
# Epoch: Epoch: 32/100 	Training Loss: 0.006971 	Training Accuracy: 95.124119 	Valid Loss: 0.222655 	Valid Acc: 66.725525
# Train: [0/44419 (0%)]	Loss: 0.002609
# Train: [150/44419 (21%)]	Loss: 0.009512
# Train: [300/44419 (41%)]	Loss: 0.007067
# Train: [450/44419 (62%)]	Loss: 0.005314
# Train: [600/44419 (82%)]	Loss: 0.006394
# Epoch: Epoch: 33/100 	Training Loss: 0.006853 	Training Accuracy: 94.647988 	Valid Loss: 0.241644 	Valid Acc: 65.522252
# Train: [0/44419 (0%)]	Loss: 0.019754
# Train: [150/44419 (21%)]	Loss: 0.004587
# Train: [300/44419 (41%)]	Loss: 0.008424
# Train: [450/44419 (62%)]	Loss: 0.018288
# Train: [600/44419 (82%)]	Loss: 0.018478
# Epoch: Epoch: 34/100 	Training Loss: 0.014139 	Training Accuracy: 93.486538 	Valid Loss: 0.241836 	Valid Acc: 63.228952
# Train: [0/44419 (0%)]	Loss: 0.007393
# Train: [150/44419 (21%)]	Loss: 0.017553
# Train: [300/44419 (41%)]	Loss: 0.010198
# Train: [450/44419 (62%)]	Loss: 0.009298
# Train: [600/44419 (82%)]	Loss: 0.019263
# Epoch: Epoch: 35/100 	Training Loss: 0.015651 	Training Accuracy: 91.772305 	Valid Loss: 0.225957 	Valid Acc: 66.792496
# Train: [0/44419 (0%)]	Loss: 0.041567
# Train: [150/44419 (21%)]	Loss: 0.014494
# Train: [300/44419 (41%)]	Loss: 0.008571
# Train: [450/44419 (62%)]	Loss: 0.010039
# Train: [600/44419 (82%)]	Loss: 0.006109
# Epoch: Epoch: 36/100 	Training Loss: 0.009457 	Training Accuracy: 90.791776 	Valid Loss: 0.230188 	Valid Acc: 68.197254
# Train: [0/44419 (0%)]	Loss: 0.000324
# Train: [150/44419 (21%)]	Loss: 0.003892
# Train: [300/44419 (41%)]	Loss: 0.001752
# Train: [450/44419 (62%)]	Loss: 0.001182
# Train: [600/44419 (82%)]	Loss: 0.003886
# Epoch: Epoch: 37/100 	Training Loss: 0.003939 	Training Accuracy: 95.472640 	Valid Loss: 0.224491 	Valid Acc: 68.327722
# Train: [0/44419 (0%)]	Loss: 0.001291
# Train: [150/44419 (21%)]	Loss: 0.004393
# Train: [300/44419 (41%)]	Loss: 0.001965
# Train: [450/44419 (62%)]	Loss: 0.004691
# Train: [600/44419 (82%)]	Loss: 0.004325
# Epoch: Epoch: 38/100 	Training Loss: 0.004161 	Training Accuracy: 95.316660 	Valid Loss: 0.211513 	Valid Acc: 66.264840
# Train: [0/44419 (0%)]	Loss: 0.005817
# Train: [150/44419 (21%)]	Loss: 0.005214
# Train: [300/44419 (41%)]	Loss: 0.003680
# Train: [450/44419 (62%)]	Loss: 0.004383
# Train: [600/44419 (82%)]	Loss: 0.008223
# Epoch: Epoch: 39/100 	Training Loss: 0.006873 	Training Accuracy: 93.696302 	Valid Loss: 0.273252 	Valid Acc: 62.756408
# Train: [0/44419 (0%)]	Loss: 0.002252
# Train: [150/44419 (21%)]	Loss: 0.025727
# Train: [300/44419 (41%)]	Loss: 0.046981
# Train: [450/44419 (62%)]	Loss: 0.029883
# Train: [600/44419 (82%)]	Loss: 0.016457
# Epoch: Epoch: 40/100 	Training Loss: 0.026062 	Training Accuracy: 90.995907 	Valid Loss: 0.204823 	Valid Acc: 68.270241
# Train: [0/44419 (0%)]	Loss: 0.007651
# Train: [150/44419 (21%)]	Loss: 0.004129
# Train: [300/44419 (41%)]	Loss: 0.003012
# Train: [450/44419 (62%)]	Loss: 0.007228
# Train: [600/44419 (82%)]	Loss: 0.006039
# Epoch: Epoch: 41/100 	Training Loss: 0.005727 	Training Accuracy: 97.453719 	Valid Loss: 0.228546 	Valid Acc: 69.823734
# Train: [0/44419 (0%)]	Loss: 0.000826
# Train: [150/44419 (21%)]	Loss: 0.006871
# Train: [300/44419 (41%)]	Loss: 0.002317
# Train: [450/44419 (62%)]	Loss: 0.004247
# Train: [600/44419 (82%)]	Loss: 0.002035
# Epoch: Epoch: 42/100 	Training Loss: 0.003719 	Training Accuracy: 94.962262 	Valid Loss: 0.219716 	Valid Acc: 70.443585
# Train: [0/44419 (0%)]	Loss: 0.000234
# Train: [150/44419 (21%)]	Loss: 0.002517
# Train: [300/44419 (41%)]	Loss: 0.003837
# Train: [450/44419 (62%)]	Loss: 0.001954
# Train: [600/44419 (82%)]	Loss: 0.001332
# Epoch: Epoch: 43/100 	Training Loss: 0.002176 	Training Accuracy: 95.516078 	Valid Loss: 0.215453 	Valid Acc: 71.639727
# Train: [0/44419 (0%)]	Loss: 0.000516
# Train: [150/44419 (21%)]	Loss: 0.000617
# Train: [300/44419 (41%)]	Loss: 0.001405
# Train: [450/44419 (62%)]	Loss: 0.001377
# Train: [600/44419 (82%)]	Loss: 0.001971
# Epoch: Epoch: 44/100 	Training Loss: 0.001619 	Training Accuracy: 97.743726 	Valid Loss: 0.221788 	Valid Acc: 70.402321
# Train: [0/44419 (0%)]	Loss: 0.000111
# Train: [150/44419 (21%)]	Loss: 0.000962
# Train: [300/44419 (41%)]	Loss: 0.000668
# Train: [450/44419 (62%)]	Loss: 0.001459
# Train: [600/44419 (82%)]	Loss: 0.001308
# Epoch: Epoch: 45/100 	Training Loss: 0.001276 	Training Accuracy: 95.656570 	Valid Loss: 0.214396 	Valid Acc: 71.157974
# Train: [0/44419 (0%)]	Loss: 0.000049
# Train: [150/44419 (21%)]	Loss: 0.001186
# Train: [300/44419 (41%)]	Loss: 0.000825
# Train: [450/44419 (62%)]	Loss: 0.000335
# Train: [600/44419 (82%)]	Loss: 0.001904
# Epoch: Epoch: 46/100 	Training Loss: 0.001745 	Training Accuracy: 97.706325 	Valid Loss: 0.239901 	Valid Acc: 69.435802
# Train: [0/44419 (0%)]	Loss: 0.000989
# Train: [150/44419 (21%)]	Loss: 0.010138
# Train: [300/44419 (41%)]	Loss: 0.040803
# Train: [450/44419 (62%)]	Loss: 0.047699
# Train: [600/44419 (82%)]	Loss: 0.048784
# Epoch: Epoch: 47/100 	Training Loss: 0.038103 	Training Accuracy: 91.298867 	Valid Loss: 0.231591 	Valid Acc: 61.780243
# Train: [0/44419 (0%)]	Loss: 0.005262
# Train: [150/44419 (21%)]	Loss: 0.015570
# Train: [300/44419 (41%)]	Loss: 0.010532
# Train: [450/44419 (62%)]	Loss: 0.009834
# Train: [600/44419 (82%)]	Loss: 0.008339
# Epoch: Epoch: 48/100 	Training Loss: 0.010613 	Training Accuracy: 92.919969 	Valid Loss: 0.212778 	Valid Acc: 67.325503
# Train: [0/44419 (0%)]	Loss: 0.027876
# Train: [150/44419 (21%)]	Loss: 0.006499
# Train: [300/44419 (41%)]	Loss: 0.010451
# Train: [450/44419 (62%)]	Loss: 0.005478
# Train: [600/44419 (82%)]	Loss: 0.003178
# Epoch: Epoch: 49/100 	Training Loss: 0.006071 	Training Accuracy: 93.926158 	Valid Loss: 0.215982 	Valid Acc: 70.973268
# Train: [0/44419 (0%)]	Loss: 0.020238
# Train: [150/44419 (21%)]	Loss: 0.002200
# Train: [300/44419 (41%)]	Loss: 0.002484
# Train: [450/44419 (62%)]	Loss: 0.002686
# Train: [600/44419 (82%)]	Loss: 0.001135
# Epoch: Epoch: 50/100 	Training Loss: 0.002148 	Training Accuracy: 97.696424 	Valid Loss: 0.210050 	Valid Acc: 70.762031
# Train: [0/44419 (0%)]	Loss: 0.000384
# Train: [150/44419 (21%)]	Loss: 0.003086
# Train: [300/44419 (41%)]	Loss: 0.001480
# Train: [450/44419 (62%)]	Loss: 0.001131
# Train: [600/44419 (82%)]	Loss: 0.001709
# Epoch: Epoch: 51/100 	Training Loss: 0.001732 	Training Accuracy: 97.708151 	Valid Loss: 0.211743 	Valid Acc: 72.040545
# Train: [0/44419 (0%)]	Loss: 0.004749
# Train: [150/44419 (21%)]	Loss: 0.000810
# Train: [300/44419 (41%)]	Loss: 0.000699
# Train: [450/44419 (62%)]	Loss: 0.001533
# Train: [600/44419 (82%)]	Loss: 0.000445
# Epoch: Epoch: 52/100 	Training Loss: 0.001095 	Training Accuracy: 97.730375 	Valid Loss: 0.214261 	Valid Acc: 70.577126
# Train: [0/44419 (0%)]	Loss: 0.000226
# Train: [150/44419 (21%)]	Loss: 0.000516
# Train: [300/44419 (41%)]	Loss: 0.000493
# Train: [450/44419 (62%)]	Loss: 0.001105
# Train: [600/44419 (82%)]	Loss: 0.001721
# Epoch: Epoch: 53/100 	Training Loss: 0.001027 	Training Accuracy: 97.778257 	Valid Loss: 0.216369 	Valid Acc: 72.474492
# Train: [0/44419 (0%)]	Loss: 0.000024
# Train: [150/44419 (21%)]	Loss: 0.000564
# Train: [300/44419 (41%)]	Loss: 0.001291
# Train: [450/44419 (62%)]	Loss: 0.000901
# Train: [600/44419 (82%)]	Loss: 0.000811
# Epoch: Epoch: 54/100 	Training Loss: 0.001168 	Training Accuracy: 97.748366 	Valid Loss: 0.223958 	Valid Acc: 71.357608
# Train: [0/44419 (0%)]	Loss: 0.000032
# Train: [150/44419 (21%)]	Loss: 0.000715
# Train: [300/44419 (41%)]	Loss: 0.000905
# Train: [450/44419 (62%)]	Loss: 0.000675
# Train: [600/44419 (82%)]	Loss: 0.001719
# Epoch: Epoch: 55/100 	Training Loss: 0.000959 	Training Accuracy: 97.749421 	Valid Loss: 0.215644 	Valid Acc: 72.561945
# Train: [0/44419 (0%)]	Loss: 0.007320
# Train: [150/44419 (21%)]	Loss: 0.000273
# Train: [300/44419 (41%)]	Loss: 0.001141
# Train: [450/44419 (62%)]	Loss: 0.001766
# Train: [600/44419 (82%)]	Loss: 0.001222
# Epoch: Epoch: 56/100 	Training Loss: 0.001090 	Training Accuracy: 97.720692 	Valid Loss: 0.221512 	Valid Acc: 69.988693
# Train: [0/44419 (0%)]	Loss: 0.000092
# Train: [150/44419 (21%)]	Loss: 0.000267
# Train: [300/44419 (41%)]	Loss: 0.000540
# Train: [450/44419 (62%)]	Loss: 0.001790
# Train: [600/44419 (82%)]	Loss: 0.001044
# Epoch: Epoch: 57/100 	Training Loss: 0.000951 	Training Accuracy: 97.741747 	Valid Loss: 0.220630 	Valid Acc: 69.221228
# Train: [0/44419 (0%)]	Loss: 0.000025
# Train: [150/44419 (21%)]	Loss: 0.001473
# Train: [300/44419 (41%)]	Loss: 0.001014
# Train: [450/44419 (62%)]	Loss: 0.000055
# Train: [600/44419 (82%)]	Loss: 0.000780
# Epoch: Epoch: 58/100 	Training Loss: 0.000941 	Training Accuracy: 97.749774 	Valid Loss: 0.228613 	Valid Acc: 72.645307
# Train: [0/44419 (0%)]	Loss: 0.000019
# Train: [150/44419 (21%)]	Loss: 0.000292
# Train: [300/44419 (41%)]	Loss: 0.001053
# Train: [450/44419 (62%)]	Loss: 0.000881
# Train: [600/44419 (82%)]	Loss: 0.001951
# Epoch: Epoch: 59/100 	Training Loss: 0.001187 	Training Accuracy: 97.754836 	Valid Loss: 0.244558 	Valid Acc: 71.186870
# Train: [0/44419 (0%)]	Loss: 0.000173
# Train: [150/44419 (21%)]	Loss: 0.003118
# Train: [300/44419 (41%)]	Loss: 0.000985
# Train: [450/44419 (62%)]	Loss: 0.039597
# Train: [600/44419 (82%)]	Loss: 0.118872
# Epoch: Epoch: 60/100 	Training Loss: 0.043260 	Training Accuracy: 85.643065 	Valid Loss: 0.262731 	Valid Acc: 59.194790
# Train: [0/44419 (0%)]	Loss: 0.013869
# Train: [150/44419 (21%)]	Loss: 0.032911
# Train: [300/44419 (41%)]	Loss: 0.028800
# Train: [450/44419 (62%)]	Loss: 0.024502
# Train: [600/44419 (82%)]	Loss: 0.014784
# Epoch: Epoch: 61/100 	Training Loss: 0.022498 	Training Accuracy: 90.442905 	Valid Loss: 0.195298 	Valid Acc: 68.071644
# Train: [0/44419 (0%)]	Loss: 0.000357
# Train: [150/44419 (21%)]	Loss: 0.006794
# Train: [300/44419 (41%)]	Loss: 0.005875
# Train: [450/44419 (62%)]	Loss: 0.007317
# Train: [600/44419 (82%)]	Loss: 0.003643
# Epoch: Epoch: 62/100 	Training Loss: 0.005663 	Training Accuracy: 97.117063 	Valid Loss: 0.198246 	Valid Acc: 69.160028
# Train: [0/44419 (0%)]	Loss: 0.000491
# Train: [150/44419 (21%)]	Loss: 0.002503
# Train: [300/44419 (41%)]	Loss: 0.002756
# Train: [450/44419 (62%)]	Loss: 0.002172
# Train: [600/44419 (82%)]	Loss: 0.004614
# Epoch: Epoch: 63/100 	Training Loss: 0.004805 	Training Accuracy: 95.541336 	Valid Loss: 0.240111 	Valid Acc: 67.266008
# Train: [0/44419 (0%)]	Loss: 0.024816
# Train: [150/44419 (21%)]	Loss: 0.009169
# Train: [300/44419 (41%)]	Loss: 0.007673
# Train: [450/44419 (62%)]	Loss: 0.004103
# Train: [600/44419 (82%)]	Loss: 0.002382
# Epoch: Epoch: 64/100 	Training Loss: 0.005604 	Training Accuracy: 95.445929 	Valid Loss: 0.224424 	Valid Acc: 68.767399
# Train: [0/44419 (0%)]	Loss: 0.000184
# Train: [150/44419 (21%)]	Loss: 0.002596
# Train: [300/44419 (41%)]	Loss: 0.001351
# Train: [450/44419 (62%)]	Loss: 0.000964
# Train: [600/44419 (82%)]	Loss: 0.000959
# Epoch: Epoch: 65/100 	Training Loss: 0.001549 	Training Accuracy: 97.741172 	Valid Loss: 0.216525 	Valid Acc: 69.375268
# Train: [0/44419 (0%)]	Loss: 0.000085
# Train: [150/44419 (21%)]	Loss: 0.000850
# Train: [300/44419 (41%)]	Loss: 0.001317
# Train: [450/44419 (62%)]	Loss: 0.001150
# Train: [600/44419 (82%)]	Loss: 0.000881
# Epoch: Epoch: 66/100 	Training Loss: 0.001103 	Training Accuracy: 97.714395 	Valid Loss: 0.218942 	Valid Acc: 68.696438
# Train: [0/44419 (0%)]	Loss: 0.000034
# Train: [150/44419 (21%)]	Loss: 0.000466
# Train: [300/44419 (41%)]	Loss: 0.000274
# Train: [450/44419 (62%)]	Loss: 0.000982
# Train: [600/44419 (82%)]	Loss: 0.002077
# Epoch: Epoch: 67/100 	Training Loss: 0.000891 	Training Accuracy: 97.754790 	Valid Loss: 0.222797 	Valid Acc: 68.832394
# Train: [0/44419 (0%)]	Loss: 0.000069
# Train: [150/44419 (21%)]	Loss: 0.001012
# Train: [300/44419 (41%)]	Loss: 0.000516
# Train: [450/44419 (62%)]	Loss: 0.001105
# Train: [600/44419 (82%)]	Loss: 0.000755
# Epoch: Epoch: 68/100 	Training Loss: 0.001000 	Training Accuracy: 97.747225 	Valid Loss: 0.223349 	Valid Acc: 68.612159
# Train: [0/44419 (0%)]	Loss: 0.000089
# Train: [150/44419 (21%)]	Loss: 0.000817
# Train: [300/44419 (41%)]	Loss: 0.000861
# Train: [450/44419 (62%)]	Loss: 0.000450
# Train: [600/44419 (82%)]	Loss: 0.001524
# Epoch: Epoch: 69/100 	Training Loss: 0.000810 	Training Accuracy: 97.758570 	Valid Loss: 0.221116 	Valid Acc: 69.560594
# Train: [0/44419 (0%)]	Loss: 0.000018
# Train: [150/44419 (21%)]	Loss: 0.000437
# Train: [300/44419 (41%)]	Loss: 0.001020
# Train: [450/44419 (62%)]	Loss: 0.001156
# Train: [600/44419 (82%)]	Loss: 0.000902
# Epoch: Epoch: 70/100 	Training Loss: 0.000981 	Training Accuracy: 97.740825 	Valid Loss: 0.223810 	Valid Acc: 69.066914
# Train: [0/44419 (0%)]	Loss: 0.000037
# Train: [150/44419 (21%)]	Loss: 0.000197
# Train: [300/44419 (41%)]	Loss: 0.000458
# Train: [450/44419 (62%)]	Loss: 0.001227
# Train: [600/44419 (82%)]	Loss: 0.002409
# Epoch: Epoch: 71/100 	Training Loss: 0.000923 	Training Accuracy: 97.706452 	Valid Loss: 0.224422 	Valid Acc: 69.961076
# Train: [0/44419 (0%)]	Loss: 0.000028
# Train: [150/44419 (21%)]	Loss: 0.000621
# Train: [300/44419 (41%)]	Loss: 0.000887
# Train: [450/44419 (62%)]	Loss: 0.000460
# Train: [600/44419 (82%)]	Loss: 0.000706
# Epoch: Epoch: 72/100 	Training Loss: 0.000900 	Training Accuracy: 97.776196 	Valid Loss: 0.227168 	Valid Acc: 70.599348
# Train: [0/44419 (0%)]	Loss: 0.000028
# Train: [150/44419 (21%)]	Loss: 0.001041
# Train: [300/44419 (41%)]	Loss: 0.000335
# Train: [450/44419 (62%)]	Loss: 0.001361
# Train: [600/44419 (82%)]	Loss: 0.000540
# Epoch: Epoch: 73/100 	Training Loss: 0.000860 	Training Accuracy: 97.745253 	Valid Loss: 0.230087 	Valid Acc: 69.248232
# Train: [0/44419 (0%)]	Loss: 0.000017
# Train: [150/44419 (21%)]	Loss: 0.000501
# Train: [300/44419 (41%)]	Loss: 0.001027
# Train: [450/44419 (62%)]	Loss: 0.000827
# Train: [600/44419 (82%)]	Loss: 0.000771
# Epoch: Epoch: 74/100 	Training Loss: 0.000777 	Training Accuracy: 97.779728 	Valid Loss: 0.234291 	Valid Acc: 69.124134
# Train: [0/44419 (0%)]	Loss: 0.000167
# Train: [150/44419 (21%)]	Loss: 0.000400
# Train: [300/44419 (41%)]	Loss: 0.000786
# Train: [450/44419 (62%)]	Loss: 0.000848
# Train: [600/44419 (82%)]	Loss: 0.001135
# Epoch: Epoch: 75/100 	Training Loss: 0.001021 	Training Accuracy: 97.790461 	Valid Loss: 0.252999 	Valid Acc: 69.314775
# Train: [0/44419 (0%)]	Loss: 0.000065
# Train: [150/44419 (21%)]	Loss: 0.001028
# Train: [300/44419 (41%)]	Loss: 0.021005
# Train: [450/44419 (62%)]	Loss: 0.101267
# Train: [600/44419 (82%)]	Loss: 0.064354
# Epoch: Epoch: 76/100 	Training Loss: 0.046043 	Training Accuracy: 84.907057 	Valid Loss: 0.213516 	Valid Acc: 65.714169
# Train: [0/44419 (0%)]	Loss: 0.046172
# Train: [150/44419 (21%)]	Loss: 0.021382
# Train: [300/44419 (41%)]	Loss: 0.011855
# Train: [450/44419 (62%)]	Loss: 0.014719
# Train: [600/44419 (82%)]	Loss: 0.014544
# Epoch: Epoch: 77/100 	Training Loss: 0.014674 	Training Accuracy: 91.601864 	Valid Loss: 0.227039 	Valid Acc: 68.051838
# Train: [0/44419 (0%)]	Loss: 0.005478
# Train: [150/44419 (21%)]	Loss: 0.005911
# Train: [300/44419 (41%)]	Loss: 0.005818
# Train: [450/44419 (62%)]	Loss: 0.003288
# Train: [600/44419 (82%)]	Loss: 0.004261
# Epoch: Epoch: 78/100 	Training Loss: 0.004934 	Training Accuracy: 94.232982 	Valid Loss: 0.227248 	Valid Acc: 67.264790
# Train: [0/44419 (0%)]	Loss: 0.042306
# Train: [150/44419 (21%)]	Loss: 0.002947
# Train: [300/44419 (41%)]	Loss: 0.005923
# Train: [450/44419 (62%)]	Loss: 0.003857
# Train: [600/44419 (82%)]	Loss: 0.007725
# Epoch: Epoch: 79/100 	Training Loss: 0.005172 	Training Accuracy: 95.496977 	Valid Loss: 0.221968 	Valid Acc: 67.771494
# Train: [0/44419 (0%)]	Loss: 0.001496
# Train: [150/44419 (21%)]	Loss: 0.001593
# Train: [300/44419 (41%)]	Loss: 0.001864
# Train: [450/44419 (62%)]	Loss: 0.002753
# Train: [600/44419 (82%)]	Loss: 0.002680
# Epoch: Epoch: 80/100 	Training Loss: 0.002445 	Training Accuracy: 97.744011 	Valid Loss: 0.221048 	Valid Acc: 68.462911
# Train: [0/44419 (0%)]	Loss: 0.000111
# Train: [150/44419 (21%)]	Loss: 0.000973
# Train: [300/44419 (41%)]	Loss: 0.001202
# Train: [450/44419 (62%)]	Loss: 0.002275
# Train: [600/44419 (82%)]	Loss: 0.000613
# Epoch: Epoch: 81/100 	Training Loss: 0.001282 	Training Accuracy: 97.717411 	Valid Loss: 0.229347 	Valid Acc: 68.378867
# Train: [0/44419 (0%)]	Loss: 0.000170
# Train: [150/44419 (21%)]	Loss: 0.000606
# Train: [300/44419 (41%)]	Loss: 0.001287
# Train: [450/44419 (62%)]	Loss: 0.001637
# Train: [600/44419 (82%)]	Loss: 0.001408
# Epoch: Epoch: 82/100 	Training Loss: 0.001345 	Training Accuracy: 97.774821 	Valid Loss: 0.229423 	Valid Acc: 69.286689
# Train: [0/44419 (0%)]	Loss: 0.000134
# Train: [150/44419 (21%)]	Loss: 0.001617
# Train: [300/44419 (41%)]	Loss: 0.000884
# Train: [450/44419 (62%)]	Loss: 0.000975
# Train: [600/44419 (82%)]	Loss: 0.002171
# Epoch: Epoch: 83/100 	Training Loss: 0.001256 	Training Accuracy: 97.768738 	Valid Loss: 0.227795 	Valid Acc: 68.514661
# Train: [0/44419 (0%)]	Loss: 0.000054
# Train: [150/44419 (21%)]	Loss: 0.001486
# Train: [300/44419 (41%)]	Loss: 0.001402
# Train: [450/44419 (62%)]	Loss: 0.002654
# Train: [600/44419 (82%)]	Loss: 0.001197
# Epoch: Epoch: 84/100 	Training Loss: 0.001922 	Training Accuracy: 95.581020 	Valid Loss: 0.228437 	Valid Acc: 69.155443
# Train: [0/44419 (0%)]	Loss: 0.000055
# Train: [150/44419 (21%)]	Loss: 0.000487
# Train: [300/44419 (41%)]	Loss: 0.000573
# Train: [450/44419 (62%)]	Loss: 0.001169
# Train: [600/44419 (82%)]	Loss: 0.002462
# Epoch: Epoch: 85/100 	Training Loss: 0.001943 	Training Accuracy: 97.525294 	Valid Loss: 0.252563 	Valid Acc: 64.430836
# Train: [0/44419 (0%)]	Loss: 0.004574
# Train: [150/44419 (21%)]	Loss: 0.004467
# Train: [300/44419 (41%)]	Loss: 0.022877
# Train: [450/44419 (62%)]	Loss: 0.026169
# Train: [600/44419 (82%)]	Loss: 0.022756
# Epoch: Epoch: 86/100 	Training Loss: 0.018054 	Training Accuracy: 93.293292 	Valid Loss: 0.291642 	Valid Acc: 64.755800
# Train: [0/44419 (0%)]	Loss: 0.001548
# Train: [150/44419 (21%)]	Loss: 0.010261
# Train: [300/44419 (41%)]	Loss: 0.005979
# Train: [450/44419 (62%)]	Loss: 0.006480
# Train: [600/44419 (82%)]	Loss: 0.003553
# Epoch: Epoch: 87/100 	Training Loss: 0.006528 	Training Accuracy: 96.193325 	Valid Loss: 0.251827 	Valid Acc: 67.170848
# Train: [0/44419 (0%)]	Loss: 0.012744
# Train: [150/44419 (21%)]	Loss: 0.003324
# Train: [300/44419 (41%)]	Loss: 0.003181
# Train: [450/44419 (62%)]	Loss: 0.001657
# Train: [600/44419 (82%)]	Loss: 0.004335
# Epoch: Epoch: 88/100 	Training Loss: 0.003827 	Training Accuracy: 97.627101 	Valid Loss: 0.269300 	Valid Acc: 67.220023
# Train: [0/44419 (0%)]	Loss: 0.000299
# Train: [150/44419 (21%)]	Loss: 0.003546
# Train: [300/44419 (41%)]	Loss: 0.005085
# Train: [450/44419 (62%)]	Loss: 0.003488
# Train: [600/44419 (82%)]	Loss: 0.002254
# Epoch: Epoch: 89/100 	Training Loss: 0.003546 	Training Accuracy: 96.560446 	Valid Loss: 0.257200 	Valid Acc: 68.185179
# Train: [0/44419 (0%)]	Loss: 0.000033
# Train: [150/44419 (21%)]	Loss: 0.003069
# Train: [300/44419 (41%)]	Loss: 0.002695
# Train: [450/44419 (62%)]	Loss: 0.003247
# Train: [600/44419 (82%)]	Loss: 0.006914
# Epoch: Epoch: 90/100 	Training Loss: 0.004405 	Training Accuracy: 97.253218 	Valid Loss: 0.260596 	Valid Acc: 64.068745
# Train: [0/44419 (0%)]	Loss: 0.017556
# Train: [150/44419 (21%)]	Loss: 0.005173
# Train: [300/44419 (41%)]	Loss: 0.002321
# Train: [450/44419 (62%)]	Loss: 0.004286
# Train: [600/44419 (82%)]	Loss: 0.004630
# Epoch: Epoch: 91/100 	Training Loss: 0.003730 	Training Accuracy: 96.930369 	Valid Loss: 0.250743 	Valid Acc: 69.701431
# Train: [0/44419 (0%)]	Loss: 0.006739
# Train: [150/44419 (21%)]	Loss: 0.000758
# Train: [300/44419 (41%)]	Loss: 0.001082
# Train: [450/44419 (62%)]	Loss: 0.000781
# Train: [600/44419 (82%)]	Loss: 0.000710
# Epoch: Epoch: 92/100 	Training Loss: 0.001020 	Training Accuracy: 97.744361 	Valid Loss: 0.244662 	Valid Acc: 67.217365
# Train: [0/44419 (0%)]	Loss: 0.000133
# Train: [150/44419 (21%)]	Loss: 0.000538
# Train: [300/44419 (41%)]	Loss: 0.000500
# Train: [450/44419 (62%)]	Loss: 0.000557
# Train: [600/44419 (82%)]	Loss: 0.000317
# Epoch: Epoch: 93/100 	Training Loss: 0.000694 	Training Accuracy: 97.780587 	Valid Loss: 0.247012 	Valid Acc: 67.712548
# Train: [0/44419 (0%)]	Loss: 0.000016
# Train: [150/44419 (21%)]	Loss: 0.000882
# Train: [300/44419 (41%)]	Loss: 0.000418
# Train: [450/44419 (62%)]	Loss: 0.000979
# Train: [600/44419 (82%)]	Loss: 0.002016
# Epoch: Epoch: 94/100 	Training Loss: 0.000999 	Training Accuracy: 97.776503 	Valid Loss: 0.245012 	Valid Acc: 68.001551
# Train: [0/44419 (0%)]	Loss: 0.000029
# Train: [150/44419 (21%)]	Loss: 0.000184
# Train: [300/44419 (41%)]	Loss: 0.000533
# Train: [450/44419 (62%)]	Loss: 0.001058
# Train: [600/44419 (82%)]	Loss: 0.000851
# Epoch: Epoch: 95/100 	Training Loss: 0.000793 	Training Accuracy: 97.754801 	Valid Loss: 0.248323 	Valid Acc: 69.624163
# Train: [0/44419 (0%)]	Loss: 0.000017
# Train: [150/44419 (21%)]	Loss: 0.000740
# Train: [300/44419 (41%)]	Loss: 0.000429
# Train: [450/44419 (62%)]	Loss: 0.001005
# Train: [600/44419 (82%)]	Loss: 0.000660
# Epoch: Epoch: 96/100 	Training Loss: 0.000688 	Training Accuracy: 97.791862 	Valid Loss: 0.251849 	Valid Acc: 67.669912
# Train: [0/44419 (0%)]	Loss: 0.000010
# Train: [150/44419 (21%)]	Loss: 0.000465
# Train: [300/44419 (41%)]	Loss: 0.000028
# Train: [450/44419 (62%)]	Loss: 0.000181
# Train: [600/44419 (82%)]	Loss: 0.001382
# Epoch: Epoch: 97/100 	Training Loss: 0.000646 	Training Accuracy: 97.761047 	Valid Loss: 0.250003 	Valid Acc: 69.807766
# Train: [0/44419 (0%)]	Loss: 0.000010
# Train: [150/44419 (21%)]	Loss: 0.000271
# Train: [300/44419 (41%)]	Loss: 0.002068
# Train: [450/44419 (62%)]	Loss: 0.009823
# Train: [600/44419 (82%)]	Loss: 0.043348
# Epoch: Epoch: 98/100 	Training Loss: 0.019947 	Training Accuracy: 95.792304 	Valid Loss: 0.326463 	Valid Acc: 63.035828
# Train: [0/44419 (0%)]	Loss: 0.014985
# Train: [150/44419 (21%)]	Loss: 0.023753
# Train: [300/44419 (41%)]	Loss: 0.010610
# Train: [450/44419 (62%)]	Loss: 0.009506
# Train: [600/44419 (82%)]	Loss: 0.010882
# Epoch: Epoch: 99/100 	Training Loss: 0.013670 	Training Accuracy: 90.119150 	Valid Loss: 0.244113 	Valid Acc: 65.693117
# Train: [0/44419 (0%)]	Loss: 0.001506
# Train: [150/44419 (21%)]	Loss: 0.003314
# Train: [300/44419 (41%)]	Loss: 0.003045
# Train: [450/44419 (62%)]	Loss: 0.002793
# Train: [600/44419 (82%)]	Loss: 0.004839
# Epoch: Epoch: 100/100 	Training Loss: 0.003620 	Training Accuracy: 96.476804 	Valid Loss: 0.240056 	Valid Acc: 66.194406

# %%
torch.save({
            'epoch': 100,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': 0.025,
            }, experiment_name+'100epoch.pt')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
# write training results:
f = open(experiment_name+ "_result"+".csv", "w")
f.write('\t'.join(('tr_er', 'val_er')))
f.write('\n')
for (tr_er, val_er) in zip(train_losses, valid_losses,):
    items= (str(tr_er),',', str(val_er))
    f.write('\t'.join(items))
    f.write('\n')
f.close()
